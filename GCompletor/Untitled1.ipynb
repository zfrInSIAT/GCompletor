# %%
import numpy as np
data = np.load('./all_speed_data.npz')
speed_data, mask = data['arr_0'], data['arr_1']

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,8))
plt.bar(list(range(len(speed_data[1,:,0,0]))),speed_data[1,:,0,0])

plt.show()

# %%
import time,datetime

# %%
base_date = "201804"
for i in range(6,20):

    tmp = str(i).zfill(2)
    date = base_date+tmp
    tt=time.strptime(date,'%Y%m%d')
    print(date,tt.tm_wday)
    
# 工作日 2018/04/06，2018/04/09-2018/04/13， 16-19
# 周末 07-08，14-15
# Out:
# 20180406 4
# 20180407 5
# 20180408 6
# 20180409 0
# 20180410 1
# 20180411 2
# 20180412 3
# 20180413 4
# 20180414 5
# 20180415 6
# 20180416 0
# 20180417 1
# 20180418 2
# 20180419 3

# %%
t = datetime.datetime(2018,4,6)
t.isoweekday()
# Out:
# 5
